# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

sys.path.append('..')
import helper
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
np.random.seed(247)
tf.set_random_seed(247)

# %%
data_path = '../../data/RNAcompete_2013/rnacompete2013.h5'
experiments = helper.get_experiments_hdf5(data_path)

# %%
rbp_index = 69
ss_type = 'pu'
normalize_method = 'log_norm'

# load rbp dataset
train, valid, test = helper.load_dataset_hdf5(data_path, dataset_name=None, ss_type=ss_type, rbp_index=rbp_index)

# process rbp dataset
train, valid, test = helper.process_data(train, valid, test, method=normalize_method)

# %%
plt.hist(train['targets'][:,0], bins=50);
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# set output file paths
model = 'affinity_conv_net'
genome_model = helper.import_model(model)
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape
model_layers, optimization = genome_model.model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)
nnmodel.inspect_layers()

# compile neural trainer
results_path = helper.make_directory('../../test', 'RNAcompete_2013')
save_path = helper.make_directory(results_path, normalize_method+'_'+ss_type)
file_path = os.path.join(save_path, str(rbp_index)+'_'+model+'_'+ss_type)
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=file_path)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 6)
# layer2: conv1d_0
# (?, 30, 1, 32)
# layer3: conv1d_0_batch
# (?, 30, 1, 32)
# layer4: conv1d_0_active
# (?, 30, 1, 32)
# layer5: conv1d_0_maxpool
# (?, 3, 1, 32)
# layer6: conv1d_0_dropout
# (?, 3, 1, 32)
# layer7: conv1d_1
# (?, 1, 1, 128)
# layer8: conv1d_1_batch
# (?, 1, 1, 128)
# layer9: conv1d_1_active
# (?, 1, 1, 128)
# layer10: conv1d_1_dropout
# (?, 1, 1, 128)
# layer11: dense_0
# (?, 1)
# layer12: dense_0_bias
# (?, 1)
# layer13: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
# fit data
data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=100, 
                      patience=20, verbose=2, shuffle=True, save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- time=0s -- loss=1.05501 -- correlation=1.05476
#   valid loss:		0.80954
#   valid Pearson's R:	0.49164+/-0.00000
#   valid rsquare:	0.19645+/-0.00000
#   valid slope:		1.20570+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.79946 -- correlation=0.79921
#   valid loss:		0.66286
#   valid Pearson's R:	0.60897+/-0.00000
#   valid rsquare:	0.36612+/-0.00000
#   valid slope:		1.38981+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.70599 -- correlation=0.70573
#   valid loss:		0.67175
#   valid Pearson's R:	0.68632+/-0.00000
#   valid rsquare:	0.35567+/-0.00000
#   valid slope:		1.38096+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.57609 -- correlation=0.57582
#   valid loss:		0.46023
#   valid Pearson's R:	0.73924+/-0.00000
#   valid rsquare:	0.54090+/-0.00000
#   valid slope:		1.04475+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.52972 -- correlation=0.52943
#   valid loss:		0.43313
#   valid Pearson's R:	0.75530+/-0.00000
#   valid rsquare:	0.57030+/-0.00000
#   valid slope:		1.08065+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.50374 -- correlation=0.50344
#   valid loss:		0.42201
#   valid Pearson's R:	0.76216+/-0.00000
#   valid rsquare:	0.58066+/-0.00000
#   valid slope:		1.06971+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.48826 -- correlation=0.48795
#   valid loss:		0.40704
#   valid Pearson's R:	0.77024+/-0.00000
#   valid rsquare:	0.59326+/-0.00000
#   valid slope:		1.00349+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.47852 -- correlation=0.47819
#   valid loss:		0.39276
#   valid Pearson's R:	0.78035+/-0.00000
#   valid rsquare:	0.60795+/-0.00000
#   valid slope:		1.02510+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.46573 -- correlation=0.46538
#   valid loss:		0.38698
#   valid Pearson's R:	0.78476+/-0.00000
#   valid rsquare:	0.61576+/-0.00000
#   valid slope:		1.06545+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.45596 -- correlation=0.45560
#   valid loss:		0.38988
#   valid Pearson's R:	0.78341+/-0.00000
#   valid rsquare:	0.61308+/-0.00000
#   valid slope:		1.06871+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.45354 -- correlation=0.45315
#   valid loss:		0.39235
#   valid Pearson's R:	0.78867+/-0.00000
#   valid rsquare:	0.61629+/-0.00000
#   valid slope:		1.12956+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.44937 -- correlation=0.44896
#   valid loss:		0.37957
#   valid Pearson's R:	0.78968+/-0.00000
#   valid rsquare:	0.62359+/-0.00000
#   valid slope:		1.07033+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.44355 -- correlation=0.44312
#   valid loss:		0.40156
#   valid Pearson's R:	0.78831+/-0.00000
#   valid rsquare:	0.61001+/-0.00000
#   valid slope:		1.15530+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.44129 -- correlation=0.44084
#   valid loss:		0.37834
#   valid Pearson's R:	0.78970+/-0.00000
#   valid rsquare:	0.62226+/-0.00000
#   valid slope:		1.01266+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.44053 -- correlation=0.44006
#   valid loss:		0.37053
#   valid Pearson's R:	0.79405+/-0.00000
#   valid rsquare:	0.63040+/-0.00000
#   valid slope:		1.02176+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
# Epoch 16 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.43593 -- correlation=0.43544
#   valid loss:		0.37177
#   valid Pearson's R:	0.79381+/-0.00000
#   valid rsquare:	0.62963+/-0.00000
#   valid slope:		1.03545+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.44024 -- correlation=0.43973
#   valid loss:		0.37431
#   valid Pearson's R:	0.79325+/-0.00000
#   valid rsquare:	0.62888+/-0.00000
#   valid slope:		1.06888+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.43489 -- correlation=0.43436
#   valid loss:		0.37414
#   valid Pearson's R:	0.79237+/-0.00000
#   valid rsquare:	0.62770+/-0.00000
#   valid slope:		0.95817+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- time=0s -- loss=0.43214 -- correlation=0.43159
#   valid loss:		0.37286
#   valid Pearson's R:	0.79641+/-0.00000
#   valid rsquare:	0.63356+/-0.00000
#   valid slope:		1.10528+/-0.00000
# Epoch 20 out of 100
# [=======                       ] 22.6% -- time=2s -- loss=0.43058 -- correlation=0.43002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-291cc02cb6eb> in <module>()
#       2 data = {'train': train, 'valid': valid}
#       3 fit.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=100,
# ----> 4                       patience=20, verbose=2, shuffle=True, save_all=False)
#
# /home/peter/harvard/tensorflow/binder/rnabinder/deepomics/fit.pyc in train_minibatch(sess, nntrainer, data, batch_size, num_epochs, patience, verbose, shuffle, save_all, save_epochs)
#      31                                                                                         batch_size=batch_size,
#      32                                                                                         verbose=verbose,
# ---> 33 											shuffle=shuffle)
#      34
#      35                 # test current model with cross-validation data and store results
#
# /home/peter/harvard/tensorflow/binder/rnabinder/deepomics/neuralnetwork.pyc in train_epoch(self, sess, data, batch_size, verbose, shuffle)
#     306                 for i in range(num_batches):
#     307                         self.train_feed = batch_generator.next_minibatch(data, self.train_feed, self.placeholders)
# --> 308                         results = sess.run(self.train_calc, feed_dict=self.train_feed)
#     309                         metric += results[2]
#     310                         performance.add_loss(results[1])
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# load best model
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, batch_size=128, name='test', verbose=1)
# Out:
# loading model from:  ../../results/RNAcompete_2013/log_norm_pu/69_affinity_conv_net_pu_best.ckpt
#   test  loss:		0.39829
#   test  Pearson's R:	0.77666+/-0.00000
#   test  rsquare:	0.60319+/-0.00000
#   test  slope:		1.04125+/-0.00000

# %%
# plot filters
W = nnmodel.get_parameters(sess, layer='conv1d_0')[0]
fig, plt = visualize.plot_filter_logos(W[:,:,:4,:], figsize=(100,50), height=25, nt_width=10, norm=0, alphabet='rna')
#outfile = os.path.join(save_path, 'conv1_filters.pdf')
#fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight') 
#plt.close()

# %%
predictions = nntrainer.get_activations(sess, test, layer='output')
plt.scatter(predictions, test['targets'])
#outfile = os.path.join(save_path, 'test_scatter.pdf')
#fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight') 
#plt.close()

# %%
num_plots = 3
max_indices = np.argsort(predictions[:,0])[::-1]  
plot_range = range(0,num_plots)
plot_index = max_indices[plot_range]
X = test['inputs'][plot_index]

# parameters for saliency analysis
params = {'genome_model': genome_model.model, 
          'input_shape': input_shape, 
          'output_shape': output_shape, 
          'model_path': file_path+'_best.ckpt',
          'optimization': optimization
         }

# guided backprop saliency
guided_saliency = saliency.guided_backprop(X, layer='output', class_index=0, params=params)
    
for i in range(num_plots):
  
    # plot saliency comparison
    fig = plt.figure()
    plt = visualize.plot_seq_struct_saliency(np.squeeze(X)[i].T, np.squeeze(guided_saliency[i]).T, nt_width=100, norm_factor=3)
    
    #output_name = '{:.2f}'.format(predictions[i,0]) + '_' + '{:.2f}'.format(data['targets'][i,0])
    #outfile = os.path.join(save_path, output_name+'.pdf')
    #fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight') 
    #plt.close()
